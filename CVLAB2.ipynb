# %% [markdown]
# <a href="https://colab.research.google.com/github/HitenTharani/CVLAB2/blob/main/CVLAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.io import imshow

# %%
image=cv2.imread('IMG1.png')
plt.imshow( image)

# %%
ret,mask=cv2.threshold(image,50,255,cv2.THRESH_BINARY)
plt.imshow(mask)
kernel= np.ones((5,5),np.uint8)

# %%
dilation=cv2.dilate(mask,kernel,iterations=2)
plt.imshow(dilation)

# %%
erosion=cv2.erode(mask,kernel,iterations=6)
plt.imshow(erosion)

# %%
dilation=cv2.dilate(erosion,kernel,iterations=2)
plt.imshow(dilation)

# %% [markdown]
# Image 2

# %%
img=cv2.imread('IMG2.png')
plt.imshow(img)

# %%
ret,mask=cv2.threshold(img,50,255,cv2.THRESH_BINARY)
plt.imshow(mask)
kernel= np.ones((5,5),np.uint8)

# %%
opening=cv2.morphologyEx(mask,cv2.MORPH_OPEN,kernel)
plt.imshow(opening)

# %%
closing=cv2.morphologyEx(img,cv2.MORPH_CLOSE,kernel)
plt.imshow(closing)

# %% [markdown]
# image 3

# %%
img3=cv2.imread('IMG3.png')
plt.imshow(img3)

# %%
mask=img3
plt.imshow(mask)

# %%
dilation=cv2.dilate(mask,kernel,iterations=2)
plt.imshow(dilation)

# %%
erosion=cv2.erode(mask,kernel,iterations=1)
plt.imshow(erosion)

# %%
result_image= dilation - erosion
plt.imshow(result_image)

# %%
mg=cv2.morphologyEx(mask,cv2.MORPH_GRADIENT,kernel)
plt.imshow(mg)
